# %% [markdown]
# # Week 13 Discussion
# This week we will look at a data set from a retirement plan.  You will report information from the data set.

# %%
# Run this cell to set up the notebook, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
retirees = Table.read_table("Retirees.csv")
retirees.show(5)

def adjust_yos(years):
    """Adjusts Years of Service so the minimum value is 9."""
    return years + (9 - min(retirees.column('Years of Service')))

retirees['Years of Service'] = retirees.apply(adjust_yos, 'Years of Service')
def group(age):
    """Groups retirees into age categories."""
    if 65 <= age <= 67:
        return "65-67"
    elif 68 <= age <= 70:
        return "68-70"
    elif 71 <= age <= 73:
        return "71-73"
    elif 74 <= age <= 75:
        return "74-75"
    else:
        return "76+"

retirees = retirees.with_column('Age Group', retirees.apply(group, 'Current Age'))
print("Average Years of Service by Age Group:")
retirees.group('Age Group', np.average).show()
print("Counts by Age Group:")
retirees.group('Age Group').show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>EEID</th> <th>First Name</th> <th>Last Name</th> <th>Gender</th> <th>DOB</th> <th>DOH</th> <th>DOR</th> <th>Salary1</th> <th>Salary2</th> <th>Salary3</th> <th>Benefit</th> <th>Age at Retirement</th> <th>Current Age</th> <th>Age at Hire</th> <th>Years of Service</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>61  </td> <td>KAILYN    </td> <td>STEWART  </td> <td>FEMALE</td> <td>04-13-1956</td> <td>06-08-2003</td> <td>05-01-2021</td> <td>0      </td> <td>0      </td> <td>0      </td> <td>86648  </td> <td>65.0505          </td> <td>68.7171    </td> <td>47.153     </td> <td>17.8975         </td>
#         </tr>
#         <tr>
# ...

# %%
retirees.select('Current Age', 'Age Group').show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Current Age</th> <th>Age Group</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>68.7171    </td> <td>68-70    </td>
#         </tr>
#         <tr>
#             <td>72.1119    </td> <td>71-73    </td>
#         </tr>
#         <tr>
#             <td>67.1201    </td> <td>76+      </td>
#         </tr>
#         <tr>
#             <td>66.3032    </td> <td>65-67    </td>
#         </tr>
#         <tr>
#             <td>65.3224    </td> <td>65-67    </td>
#         </tr>
#         <tr>
#             <td>65.9425    </td> <td>65-67    </td>
#         </tr>
#         <tr>
#             <td>73.3333    </td> <td>76+      </td>
#         </tr>
#         <tr>
#             <td>72.8224    </td> <td>71-73    </td>
#         </tr>
#         <tr>
#             <td>71.2089    </td> <td>71-73    </td>
#         </tr>
#         <tr>
# ...
